# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("demo_weather.xlsx")
df
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# To read first 3 rows from excel workbook

df_nrows_3= pd.read_excel("demo_weather.xlsx",nrows=3)
df_nrows_3
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy

# %%
d = {'Date':['2012-10-10','12-05-2014'],"Tmep":[45,15],'Humidity':[1,5],"Weather":['Rainy','Sunny']}

# %%
df2 = pd.DataFrame(d)
df2
# Out:
#          Date  Tmep  Humidity Weather
# 0  2012-10-10    45         1   Rainy
# 1  12-05-2014    15         5   Sunny

# %%
r,c = df.shape

# %%
print(r,c)
# Out:
# 9 4

# %%
# head() gives first 5 rows from the top bydefault

df.head()
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow

# %%
#if we pass the integer number will give that much rows
df.head(3)
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy

# %%
# tail() method gives last 5 rows from the bottom bydefault,if we pass the integer number will give that much rows

df.tail(3)
# Out:
#         Date  Temperature  Humidity Weather
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
#slicing
df[2:5]
# Out:
#         Date  Temperature  Humidity Weather
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow

# %%
df[:]#or just df
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
# To get the column names of the given dataframe

df.columns
# Out:
# Index(['Date', 'Temperature', 'Humidity', 'Weather'], dtype='object')

# %%
df.columns[0]
# Out:
# 'Date'

# %%
df.columns[0:3]
# Out:
# Index(['Date', 'Temperature', 'Humidity'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df["Humidity"]
# Out:
# 0    NaN
# 1    5.0
# 2    NaN
# 3    8.0
# 4    NaN
# 5    5.0
# 6    9.0
# 7    7.0
# 8    4.0
# Name: Humidity, dtype: float64

# %%
type(df["Humidity"])
# Out:
# pandas.core.series.Series

# %%
df[["Humidity"]]
# Out:
#    Humidity
# 0       NaN
# 1       5.0
# 2       NaN
# 3       8.0
# 4       NaN
# 5       5.0
# 6       9.0
# 7       7.0
# 8       4.0

# %%
type(df[["Humidity"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.Humidity
# Out:
# 0    NaN
# 1    5.0
# 2    NaN
# 3    8.0
# 4    NaN
# 5    5.0
# 6    9.0
# 7    7.0
# 8    4.0
# Name: Humidity, dtype: float64

# %%
type(df.Humidity)
# Out:
# pandas.core.series.Series

# %%
df[["Humidity","Temperature"]]
# Out:
#    Humidity  Temperature
# 0       NaN         25.0
# 1       5.0          NaN
# 2       NaN         35.0
# 3       8.0         38.0
# 4       NaN          NaN
# 5       5.0         38.0
# 6       9.0         24.0
# 7       7.0          NaN
# 8       4.0         25.0

# %%
df.Temperature.max()
# Out:
# 38.0

# %%
df.Humidity.min()
# Out:
# 4.0

# %%
df["Temperature"].mean()
# Out:
# 30.833333333333332

# %%
df.Temperature.std()
# Out:
# 6.853223086013374

# %%
#Generate descriptive statistics.
#Descriptive statistics include those that summarize the central tendency,dispersion and shape of a dataset's distribution,excluding NaN values.
df.describe()
# Out:
#        Temperature  Humidity
# count     6.000000  6.000000
# mean     30.833333  6.333333
# std       6.853223  1.966384
# min      24.000000  4.000000
# 25%      25.000000  5.000000
# 50%      30.000000  6.000000
# 75%      37.250000  7.750000
# max      38.000000  9.000000

# %%
# Boolean Indexing
df[df.Humidity > 5]
# Out:
#         Date  Temperature  Humidity Weather
# 3 2021-12-01         38.0       8.0   Sunny
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy

# %%
df
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
#finding min temperature and returning df

df[df.Temperature == df.Temperature.min()]
# Out:
#         Date  Temperature  Humidity Weather
# 6 2019-08-14         24.0       9.0  Rainy

# %%
#finding min temperature and returning df with desired columns
df[df.Temperature == df.Temperature.min()][["Date","Temperature"]]
# Out:
#         Date  Temperature
# 6 2019-08-14         24.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
#to set index by column name
df3 = df.set_index("Date")
df3
# Out:
#             Temperature  Humidity Weather
# Date
# 2012-10-15         25.0       NaN  Rainy
# 2015-05-18          NaN       5.0     NaN
# 2018-09-14         35.0       NaN  Rainy
# 2021-12-01         38.0       8.0   Sunny
# 2020-12-09          NaN       NaN    snow
# 2022-10-08         38.0       5.0     NaN
# 2019-08-14         24.0       9.0  Rainy
# 2021-10-01          NaN       7.0   Windy
# 2014-09-04         25.0       4.0  Rainy

# %%
df3.loc["2015-05-18":"2020-12-09"]
# Out:
#             Temperature  Humidity Weather
# Date
# 2015-05-18          NaN       5.0     NaN
# 2018-09-14         35.0       NaN  Rainy
# 2020-12-09          NaN       NaN    snow
# 2019-08-14         24.0       9.0  Rainy

# %%
#To reset index 
df3.reset_index(inplace=True)
df3
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
# converting Following Dataframe into excel workbook after data manipulation
df2.to_excel("df_By_dict.xlsx")

# %%
# !pip install pandas_profiling

# %%
# !pip install pandas

# %%
import pandas_profiling as prof

# %%
p = prof.ProfileReport(df)

# %%
p.to_file("Df_by_profiling")
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.57it/s]
# c:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:262: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 200.20it/s]

# %%
df.to_excel("df_Default.xlsx")

# %%
df4 = pd.read_excel("demo_weather.xlsx")
df4
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df5 = df4.fillna(0)
df5
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       0.0  Rainy
# 1 2015-05-18          0.0       5.0       0
# 2 2018-09-14         35.0       0.0  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          0.0       0.0    snow
# 5 2022-10-08         38.0       5.0       0
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          0.0       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         9 non-null      datetime64[ns]
#  1   Temperature  9 non-null      float64
#  2   Humidity     9 non-null      float64
#  3   Weather      9 non-null      object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 416.0+ bytes

# %%
df6 = df4.fillna({"Temperature":0,"Humidity":0.0,"Weather":"No Weather"})
df6
# Out:
#         Date  Temperature  Humidity     Weather
# 0 2012-10-15         25.0       0.0      Rainy
# 1 2015-05-18          0.0       5.0  No Weather
# 2 2018-09-14         35.0       0.0      Rainy
# 3 2021-12-01         38.0       8.0       Sunny
# 4 2020-12-09          0.0       0.0        snow
# 5 2022-10-08         38.0       5.0  No Weather
# 6 2019-08-14         24.0       9.0      Rainy
# 7 2021-10-01          0.0       7.0       Windy
# 8 2014-09-04         25.0       4.0      Rainy

# %%
df4
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
#axis : {0 or 'index', 1 or 'columns'} Axis along which to fill missing values.
df6 = df4.fillna(method="ffill",axis=1)
df6
# Out:
#         Date          Temperature             Humidity Weather
# 0 2012-10-15                 25.0                 25.0  Rainy
# 1 2015-05-18  2015-05-18 00:00:00                  5.0     5.0
# 2 2018-09-14                 35.0                 35.0  Rainy
# 3 2021-12-01                 38.0                  8.0   Sunny
# 4 2020-12-09  2020-12-09 00:00:00  2020-12-09 00:00:00    snow
# 5 2022-10-08                 38.0                  5.0     5.0
# 6 2019-08-14                 24.0                  9.0  Rainy
# 7 2021-10-01  2021-10-01 00:00:00                  7.0   Windy
# 8 2014-09-04                 25.0                  4.0  Rainy

# %%
df6 = df4.fillna(method="bfill",axis="columns")
df6
# Out:
#         Date Temperature Humidity Weather
# 0 2012-10-15        25.0   Rainy   Rainy
# 1 2015-05-18         5.0      5.0     NaN
# 2 2018-09-14        35.0   Rainy   Rainy
# 3 2021-12-01        38.0      8.0   Sunny
# 4 2020-12-09        snow     snow    snow
# 5 2022-10-08        38.0      5.0     NaN
# 6 2019-08-14        24.0      9.0  Rainy
# 7 2021-10-01         7.0      7.0   Windy
# 8 2014-09-04        25.0      4.0  Rainy

# %%
df4
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
#Fill NaN values using an interpolation method.
df7 = df4.interpolate(method="pad")
df7
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18         25.0       5.0  Rainy
# 2 2018-09-14         35.0       5.0  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09         38.0       8.0    snow
# 5 2022-10-08         38.0       5.0    snow
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01         24.0       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
#Study
df8 = df3.interpolate(method="time")
df8
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\JOBANC~1\AppData\Local\Temp/ipykernel_25560/2847392419.py in <module>
#       1 #Study
# ----> 2 df8 = df3.interpolate(method="time")
#       3 df8
#
# c:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
# ...

# %%
df4.dropna()
# Out:
#         Date  Temperature  Humidity Weather
# 3 2021-12-01         38.0       8.0   Sunny
# 6 2019-08-14         24.0       9.0  Rainy

# %%
df4.isna()
# Out:
#     Date  Temperature  Humidity  Weather
# 0  False        False      True    False
# 1  False         True     False     True
# 2  False        False      True    False
# 3  False        False     False    False
# 4  False         True      True    False
# 5  False        False     False     True
# 6  False        False     False    False
# 7  False         True     False    False
# 8  False        False     False    False

# %%
df4.isnull()
# Out:
#     Date  Temperature  Humidity  Weather
# 0  False        False      True    False
# 1  False         True     False     True
# 2  False        False      True    False
# 3  False        False     False    False
# 4  False         True      True    False
# 5  False        False     False     True
# 6  False        False     False    False
# 7  False         True     False    False
# 8  False        False     False    False

# %%
df4.notna()
# Out:
#    Date  Temperature  Humidity  Weather
# 0  True         True     False     True
# 1  True        False      True    False
# 2  True         True     False     True
# 3  True         True      True     True
# 4  True        False     False     True
# 5  True         True      True    False
# 6  True         True      True     True
# 7  True        False      True     True
# 8  True         True      True     True

# %%
df4.notnull()
# Out:
#    Date  Temperature  Humidity  Weather
# 0  True         True     False     True
# 1  True        False      True    False
# 2  True         True     False     True
# 3  True         True      True     True
# 4  True        False     False     True
# 5  True         True      True    False
# 6  True         True      True     True
# 7  True        False      True     True
# 8  True         True      True     True

# %%
df4.dropna(how="any")
# Out:
#         Date  Temperature  Humidity Weather
# 3 2021-12-01         38.0       8.0   Sunny
# 6 2019-08-14         24.0       9.0  Rainy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df4.dropna(how="all")
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18          NaN       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df4.dropna(how="any",axis=0)
# Out:
#         Date  Temperature  Humidity Weather
# 3 2021-12-01         38.0       8.0   Sunny
# 6 2019-08-14         24.0       9.0  Rainy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df4.dropna(how="any",axis=1)
# Out:
#         Date
# 0 2012-10-15
# 1 2015-05-18
# 2 2018-09-14
# 3 2021-12-01
# 4 2020-12-09
# 5 2022-10-08
# 6 2019-08-14
# 7 2021-10-01
# 8 2014-09-04

# %%
df8 = pd.read_excel("demo_weather.xlsx",sheet_name="Sheet2")
df8.head()
# Out:
#         Date  Temperature  Humidity  Weather
# 0 2012-10-15           25     -9999   Rainy
# 1 2015-05-18           -5         5  Nothing
# 2 2018-09-14           35     -9999   Rainy
# 3 2021-12-01           38         8    Sunny
# 4 2020-12-09        -9999   -999911     snow

# %%
df9 = df8.replace([-9999,-999911,"Nothing"],np.nan)

df9
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18         -5.0       5.0     NaN
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0      No
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df10 = df8.replace({"Temperature":-9999,"Humidity":-999911,"Weather":"No"},np.nan)
df10.head()
# Out:
#         Date  Temperature  Humidity  Weather
# 0 2012-10-15         25.0   -9999.0   Rainy
# 1 2015-05-18         -5.0       5.0  Nothing
# 2 2018-09-14         35.0   -9999.0   Rainy
# 3 2021-12-01         38.0       8.0    Sunny
# 4 2020-12-09          NaN       NaN     snow

# %%
df11 = df10.replace({-9999:np.nan,"Nothing":"rainy"})
df11
# Out:
#         Date  Temperature  Humidity Weather
# 0 2012-10-15         25.0       NaN  Rainy
# 1 2015-05-18         -5.0       5.0   rainy
# 2 2018-09-14         35.0       NaN  Rainy
# 3 2021-12-01         38.0       8.0   Sunny
# 4 2020-12-09          NaN       NaN    snow
# 5 2022-10-08         38.0       5.0     NaN
# 6 2019-08-14         24.0       9.0  Rainy
# 7 2021-10-01          NaN       7.0   Windy
# 8 2014-09-04         25.0       4.0  Rainy

# %%
df12 = pd.read_excel("demo_weather.xlsx",sheet_name="Sheet3")
df12.head()
# Out:
#         Date Temperature Humidity Weather
# 0 2012-10-15         25F    -9999  Rainy
# 1 2015-05-18       -9999        5      No
# 2 2018-09-14          35    -9999  Rainy
# 3 2021-12-01          38        8   Sunny
# 4 2020-12-09       -9999      6mp    snow

# %%
df12.replace({"Temperature":"[A-Za-z]","Humidity":"[A-Za-z]"},"",regex=True)
# Out:
#         Date Temperature Humidity  Weather
# 0 2012-10-15          25    -9999   Rainy
# 1 2015-05-18       -9999        5       No
# 2 2018-09-14          35    -9999   Rainy
# 3 2021-12-01          38        8    Sunny
# 4 2020-12-09       -9999        6     snow
# 5 2022-10-08          38        5  Nothing
# 6 2019-08-14          24        9   Rainy
# 7 2021-10-01          35        7    Windy
# 8 2014-09-04          25        4   Rainy

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         9 non-null      datetime64[ns]
#  1   Temperature  9 non-null      object
#  2   Humidity     9 non-null      object
#  3   Weather      9 non-null      object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 416.0+ bytes

# %%
A= list(df12.Weather.unique())
A
# Out:
# ['Rainy ', 'No', 'Sunny', 'snow', 'Nothing', 'Windy']

# %%
df12.head()
# Out:
#         Date Temperature Humidity Weather
# 0 2012-10-15         25F    -9999  Rainy
# 1 2015-05-18       -9999        5      No
# 2 2018-09-14          35    -9999  Rainy
# 3 2021-12-01          38        8   Sunny
# 4 2020-12-09       -9999      6mp    snow

# %%
df12.replace(A,range(6)).head()
# Out:
#         Date Temperature Humidity  Weather
# 0 2012-10-15         25F    -9999        0
# 1 2015-05-18       -9999        5        1
# 2 2018-09-14          35    -9999        0
# 3 2021-12-01          38        8        2
# 4 2020-12-09       -9999      6mp        3

# %%
df12.replace(['Rainy ', 'No', 'Sunny', 'snow', 'Nothing', 'Windy'],[0,1,2,3,4,5])
# Out:
#         Date Temperature Humidity  Weather
# 0 2012-10-15         25F    -9999        0
# 1 2015-05-18       -9999        5        1
# 2 2018-09-14          35    -9999        0
# 3 2021-12-01          38        8        2
# 4 2020-12-09       -9999      6mp        3
# 5 2022-10-08          38        5        4
# 6 2019-08-14          24        9        0
# 7 2021-10-01         35C        7        5
# 8 2014-09-04          25        4        0
