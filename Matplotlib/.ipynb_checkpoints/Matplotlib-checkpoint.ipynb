# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
a=[1,2,3,4,5,6]
b=[11,22,33,44,55,66]

# %%
x=np.array([5,3,10,4,7])
y=np.array([9,6,8,4,2])

# %%
plt.plot(a,b)

# %%
plt.subplot(projection='polar')
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.subplot(projection='polar')
plt.bar(x,y,alpha=0.5)  #alpha=to lighten
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,marker='o')

# %%
plt.plot(x,y,marker='o',linestyle='dotted')

# %%
plt.plot(x,y,marker='o',linestyle='dashed')

# %%
plt.plot(x,y,marker='o',linestyle='dashdot',color='m')

# %%
plt.plot(x,y,marker='o',linestyle='dashdot',color='#c85f00')

# %%
plt.plot(x,y,marker='o',linestyle='dashdot',color='#c85f00',lw=4)

# %%
plt.plot(x,y,marker='o',linestyle='dashdot',color='Indigo',linewidth=5)

# %%
plt.plot(x,y,marker='o',linestyle='dashdot',color='Lavender')

# %%
plt.plot(x,y,marker='o',linestyle=':')

# %%
plt.plot(x,y,marker='o',ls=':')

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist([4,4,7,3,2,11,8,8,8,9])
# Out:
# (array([1., 1., 2., 0., 0., 1., 3., 1., 0., 1.]),
#  array([ 2. ,  2.9,  3.8,  4.7,  5.6,  6.5,  7.4,  8.3,  9.2, 10.1, 11. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x,y,marker='o',linestyle='dashdot',color='Indigo',linewidth=2)
plt.plot([1,4,7,9,5],[9,7,5,4,8],marker='o',linestyle='dashdot',color='Red',linewidth=2)

# %%
plt.plot(x,y,[1,4,7,9,5],[9,7,5,4,8],marker='o',linestyle='dashdot',linewidth=2)

# %%
plt.plot(x,y,[1,4,7,9,5],[9,7,5,4,8],marker='o',linestyle='dashdot',linewidth=2,color='Red')

# %%
plt.plot([1,4,7,9,5,4,6,9,10],[9,7,5,4,8,5,1,4,9],marker='o',linestyle='dashdot',linewidth=2)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("BMI")
# Out:
# Text(0.5, 1.0, 'BMI')

# %%
plt.plot([1,4,7,9,5,4,6,9,10],[9,7,5,4,8,5,1,4,9],marker='o',linestyle='dashdot',linewidth=2)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("BMI",fontdict={'color':'Purple','size':20},loc='right')
plt.grid()

# %%
plt.plot([1,4,7,9,5,4,6,9,10],[9,7,5,4,8,5,1,4,9],marker='o',linestyle='dashdot',linewidth=2)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("BMI",fontdict={'color':'Purple','size':20},loc='right')
plt.grid(axis='y')

# %%
plt.plot([1,4,7,9,5,4,6,9,10],[9,7,5,4,8,5,1,4,9],marker='o',linestyle='dashdot',linewidth=2)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("BMI",fontdict={'color':'Purple','size':20},loc='right')
plt.grid(color='orange',lw=3)

# %%
x1=[1,2,3,4]
y1=[10,20,30,40]
plt.subplot(1,2,1,projection='polar')
plt.plot(x1,y1)
x2=[1,2,3,4]
y2=[4,9,2,10]
plt.subplot(1,2,2,projection='polar')
plt.plot(x2,y2)

# %%
x1=[1,2,3,4]
y1=[10,20,30,40]
plt.subplot(1,2,1)
plt.plot(x1,y1)
x2=[1,2,3,4]
y2=[4,9,2,10]
plt.subplot(1,2,2)
plt.plot(x2,y2)

# %%
x1=[1,2,3,4]
y1=[10,20,30,40]
plt.subplot(2,1,1)
plt.plot(x1,y1)
x2=[1,2,3,4]
y2=[4,9,2,10]
plt.subplot(2,1,2)
plt.plot(x2,y2)

# %%
x1=[1,2,3,4]
y1=[10,20,30,40]
plt.subplot(2,4,1)
plt.plot(x1,y1)
plt.title('graph1')

x2=[1,2,3,4]
y2=[4,9,2,10]
plt.subplot(2,4,2)
plt.plot(x2,y2)
plt.title('graph2')

x3=[1,2,3,4]
y3=[6,8,9,5]
plt.subplot(2,4,3)
plt.plot(x3,y3)
plt.title('graph3')

x4=[1,2,3,4]
y4=[3,2,1,3]
plt.subplot(2,4,4)
plt.plot(x4,y4)
plt.title('graph4')

x5=[1,2,3,4]
y5=[6,8,3,4]
plt.subplot(2,4,5)
plt.plot(x5,y5)
plt.title('graph5')

x6=[1,2,3,4]
y6=[3,1,2,8]
plt.subplot(2,4,6)
plt.plot(x6,y6)
plt.title('graph6')

x7=[1,2,3,4]
y7=[5,2,6,7]
plt.subplot(2,4,7)
plt.plot(x7,y7)
plt.title('graph7')

x8=[1,2,3,4]
y8=[6,3,1,8]
plt.subplot(2,4,8)
plt.plot(x8,y8)
plt.title('graph8')

plt.suptitle("Main Graph")
# Out:
# Text(0.5, 0.98, 'Main Graph')

# %%
x=np.arange(0,4*np.pi,0.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x=np.arange(0,4*np.pi,0.5)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x=np.arange(0,4*np.pi,0.1)
y = np.cos(x)
plt.plot(x,y)
plt.show()

# %%
x=np.arange(0,4*np.pi,0.1)
y = np.tan(x)
plt.plot(x,y)
plt.show()

# %%
x2=np.linspace(0,np.pi,15)
y2=np.tan(x2)
plt.plot(x2,y2)

# %%
np.tan(0)
# Out:
# 0.0

# %%
np.tan(1/4*np.pi)
# Out:
# 0.9999999999999999

# %%
np.tan(1/2*np.pi)
# Out:
# 1.633123935319537e+16

# %%
np.tan(3/2*np.pi)
# Out:
# 5443746451065123.0

# %%
import math
math.radians(180)
# Out:
# 3.141592653589793

# %%
A=[0,np.pi*1/4,np.pi*1/2,np.pi*3/2,np.pi]
np.degrees(A)
# Out:
# array([  0.,  45.,  90., 270., 180.])

# %%
B=np.tan(np.degrees(A))

# %%
B
# Out:
# array([ 0.        ,  1.61977519, -1.99520041, -0.17883906,  1.33869021])

# %%
x=np.arange(0,4*np.pi,0.1)
plt.plot(x,np.sin(x),x,np.cos(x))
plt.legend(['sin','cos'])

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
x=np.arange(10)
y=[2,3,0,3,6,7,5,6,10,11]

# %%
plt.xlabel("X")
plt.ylabel('Y')
plt.plot(x,y,color='Red')
plt.plot(x,y,'>')
plt.savefig('New graph')

# %%
x=np.arange(10)
y=[2,3,0,3,6,7,5,6,10,11]
plt.xlabel("X")
plt.ylabel('Y')
plt.plot(x,y,color='Red')
plt.plot(x,y,'>')
plt.savefig('New graph')
plt.annotate(xy=[2,3],text='Greatest point')
plt.annotate(xy=[4,8],text='Greatest point')
plt.legend('speed',loc=4)
plt.style.use("tableau-colorblind10")

# %%
#boxplot used to represent distribution of data
d1=np.random.normal(100,10,200)
plt.boxplot(d1,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c58424cf70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c58425c6d0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1c5841adbe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c58425cdf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c5842691f0>],
#  'means': []}

# %%
data=pd.DataFrame(np.random.rand(12,6),columns=['a','b','c','d','e','f'])
data
# Out:
#            a         b         c         d         e         f
# 0   0.232511  0.191794  0.591327  0.350640  0.424462  0.405420
# 1   0.474391  0.914241  0.167788  0.247715  0.921812  0.067574
# 2   0.912269  0.018686  0.407818  0.354934  0.596756  0.676565
# 3   0.715527  0.303069  0.565637  0.296446  0.422751  0.568875
# 4   0.572813  0.511439  0.806891  0.697342  0.477783  0.227047
# 5   0.407384  0.043575  0.704878  0.081102  0.182085  0.551423
# 6   0.325032  0.295439  0.803628  0.310107  0.930779  0.326423
# 7   0.297274  0.785490  0.586732  0.813289  0.385031  0.328074
# 8   0.803553  0.570868  0.439456  0.231638  0.680998  0.605460
# 9   0.415371  0.231306  0.429454  0.023742  0.248638  0.230981
# 10  0.873708  0.547186  0.671492  0.464789  0.785190  0.553735
# 11  0.718360  0.987049  0.146595  0.756030  0.689186  0.356435

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c5842f3310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c5842f3a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c5842e2f40>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1c5843001c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1c584300550>,
# ...
#  'means': []}

# %%
data.plot.box(grid=False)
# Out:
# <AxesSubplot:>

# %%
y=[3,8,12,19,20,25,30,40,24,20,7,1]
x=np.arange(0,12)
plt.plot(x,y)
plt.fill_between(x,y,color='teal')

# %%
x1=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y1=[99,86,87,88,100,86,103,87,94,78,77,85,86]
plt.scatter(x1,y1)

# %%
x=np.arange(1,11)
y=x**2
plt.scatter(x,y)

# %%
x=np.arange(1,11) #scatter plot used to determine relation between two variables
y=x*2
plt.scatter(x,y)

# %%
x1=np.arange(1,11) #scatter plot used to determine relation between two variables
y1=x1**2
plt.scatter(x1,y1,marker='o',s=100,edgecolor='orange')

x2=np.arange(1,11)
y2=x2*2
plt.scatter(x2,y2,c='teal',marker='^',s=100,edgecolor='orange')

# %%
Brand=['puma','jockey','nike','levis','Wildcraft','peter england']
Sales=[41,23,17,15,40,38]
plt.pie(Sales,labels=Brand)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c5856f0a00>,
# ...
#  [Text(0.8121222964847729, 0.7419281471627147, 'puma'),
#   Text(-0.35123166968774855, 1.0424184928369011, 'jockey'),
#   Text(-0.9526279355804298, 0.5500000148652441, 'nike'),
#   Text(-1.0983867562937033, -0.059552779940126414, 'levis'),
#   Text(-0.5500000148652441, -0.9526279355804297, 'Wildcraft'),
#   Text(0.8510984169355177, -0.69687264596184, 'peter england')])

# %%
Brand=['puma','jockey','nike','levis','Wildcraft','peter england']
Sales=[41,23,17,15,40,38]
plt.pie(Sales,labels=Brand,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c585754340>,
# ...
#  [Text(-0.7419281471627147, 0.8121222964847729, 'puma'),
#   Text(-1.0424184928369011, -0.3512316696877485, 'jockey'),
#   Text(-0.5500000148652441, -0.9526279355804297, 'nike'),
#   Text(0.05955277994012683, -1.0983867562937033, 'levis'),
#   Text(0.9526279355804297, -0.5500000148652443, 'Wildcraft'),
#   Text(0.69687264596184, 0.8510984169355177, 'peter england')])

# %%
Brand=['puma','jockey','nike','levis','Wildcraft','peter england']
Sales=[41,23,17,15,40,38]
plt.pie(Sales,labels=Brand,startangle=90,explode=[0,0,0.1,0.2,0.4,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c5841f7af0>,
# ...
#  [Text(-0.7419281471627147, 0.8121222964847729, 'puma'),
#   Text(-1.0424184928369011, -0.3512316696877485, 'jockey'),
#   Text(-0.6000000162166299, -1.0392304751786505, 'nike'),
#   Text(0.07038055811105898, -1.2980934392561947, 'levis'),
#   Text(1.2990380939733133, -0.7500000202707877, 'Wildcraft'),
#   Text(0.69687264596184, 0.8510984169355177, 'peter england')])

# %%
Brand=['puma','jockey','nike','levis','Wildcraft','peter england']
Sales=[41,23,17,15,40,38]
plt.pie(Sales,labels=Brand,startangle=90,explode=[0,0,0.1,0.2,0.4,0],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c584151dc0>,
# ...
#  [Text(-0.7419281471627147, 0.8121222964847729, 'puma'),
#   Text(-1.0424184928369011, -0.3512316696877485, 'jockey'),
#   Text(-0.6000000162166299, -1.0392304751786505, 'nike'),
#   Text(0.07038055811105898, -1.2980934392561947, 'levis'),
#   Text(1.2990380939733133, -0.7500000202707877, 'Wildcraft'),
#   Text(0.69687264596184, 0.8510984169355177, 'peter england')])

# %%
Brand=['puma','jockey','nike','levis','Wildcraft','peter england']
Sales=[41,23,17,15,40,38]
plt.pie(Sales,labels=Brand,startangle=90,explode=[0,0,0.1,0.2,0.4,0],shadow=True,colors=['m','c','b','y','r','g'])
plt.legend(loc='upper left')

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(data,hue='sex')  #hue is as per columns

# %%
data2=sns.load_dataset('penguins')
data2.head()
sns.pairplot(data2,hue='species')

# %%
sns.swarmplot(data=data2, x='body_mass_g',y='sex',hue='species')  #this is for category
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='sex'>

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
data = [['E001', 'M', 34, 123, 'Normal', 350],
        ['E002', 'F', 40, 114, 'Overweight', 450],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]
df1=pd.DataFrame(data,columns=['Eid','Gender','Age','Sales','BMI','salary'])

# %%
df1
# Out:
#     Eid Gender  Age  Sales          BMI  salary
# 0  E001      M   34    123       Normal     350
# 1  E002      F   40    114   Overweight     450
# 2  E003      F   37    135      Obesity     169
# 3  E004      M   30    139  Underweight     189
# 4  E005      F   44    117  Underweight     183
# 5  E006      M   36    121       Normal      80
# 6  E007      M   32    133      Obesity     166
# 7  E008      F   26    140       Normal     120
# 8  E009      M   32    133       Normal      75
# 9  E010      M   36    133  Underweight      40

# %%
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Sales'}>],
#        [<AxesSubplot:title={'center':'salary'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.Gender.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.bar(df1.Gender,df1.salary)
# Out:
# <BarContainer object of 10 artists>

# %%
X = ['Group A','Group B','Group C','Group D']
girls = [10,20,20,40]
boys = [20,30,25,30]

# %%
plt.bar(X,girls,color='Red')
plt.bar(X,boys,color='Blue')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
df1.plot.box(notch=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df1.salary,df1.Sales)

# %%
plt.subplot(projection='polar')
plt.scatter(df1.salary,df1.Sales)

# %%
n=150
y=2*np.random.rand(150)

# %%
y
# Out:
# array([0.89859881, 1.45316487, 1.20688473, 1.7801019 , 0.41203245,
#        0.45462557, 0.05734663, 0.94895752, 0.82822702, 0.13795357,
#        0.5980065 , 0.98104308, 1.72462735, 1.13992077, 0.03878179,
#        0.45660148, 0.8288558 , 0.35075244, 0.59080634, 1.92233965,
#        1.36548534, 0.80155463, 1.71381975, 1.85242613, 1.90049469,
#        0.13555157, 0.70407561, 0.00422798, 1.5911123 , 1.88513493,
#        1.77765508, 0.76720402, 1.25356914, 1.28061265, 0.33074233,
#        1.65149175, 0.54890152, 0.77717305, 0.62562678, 1.77475431,
#        0.47314939, 1.71600143, 0.6897748 , 1.93958708, 0.2171096 ,
#        1.59257886, 1.30549401, 0.02538465, 1.568789  , 0.58505557,
#        0.36350652, 1.5956689 , 0.14640531, 0.47949968, 0.05386976,
#        0.57410412, 0.43299294, 1.78607996, 0.97259069, 1.87655238,
#        1.50560926, 1.59966663, 1.79601229, 1.52627659, 1.2595987 ,
#        0.86456441, 1.88901913, 0.70432187, 0.51142034, 1.25819451,
# ...

# %%
ang=2*np.pi*np.random.rand(150)
ang
# Out:
# array([5.04688602, 5.28547356, 0.63048271, 4.99236155, 4.59121099,
#        2.80557049, 4.42703981, 1.7836962 , 2.21393962, 4.02723724,
#        0.73522391, 3.88097432, 1.15016963, 4.72039013, 4.9826519 ,
#        0.61124811, 0.34355121, 4.01897619, 5.68018737, 3.16607031,
#        2.50192394, 2.15443923, 1.62290688, 1.05914866, 4.184895  ,
#        2.28571613, 3.69340238, 4.2225583 , 4.19050201, 4.57428044,
#        4.44126204, 5.0954226 , 1.95818373, 5.96377863, 0.45730715,
#        2.52322619, 4.63709392, 1.38271253, 3.67198283, 0.98573898,
#        4.57533091, 2.12961034, 5.01064458, 2.0997683 , 1.36440932,
#        0.7786464 , 2.517639  , 1.64495021, 4.00518815, 6.19411835,
#        1.46828412, 5.28553952, 2.65762394, 2.770269  , 5.34228837,
#        2.18682721, 3.72116416, 3.07235025, 5.14122043, 1.55088802,
#        5.26038019, 0.16131941, 1.5828582 , 5.76861041, 1.21811005,
#        1.62558763, 4.98383692, 3.27364262, 0.08265631, 3.9179391 ,
# ...

# %%
area=200*y**2
area
# Out:
# array([1.61495963e+02, 4.22337630e+02, 2.91314149e+02, 6.33752552e+02,
#        3.39541473e+01, 4.13368818e+01, 6.57727090e-01, 1.80104075e+02,
#        1.37192001e+02, 3.80623754e+00, 7.15223552e+01, 1.92489104e+02,
#        5.94867897e+02, 2.59883873e+02, 3.00805446e-01, 4.16969815e+01,
#        1.37400388e+02, 2.46054547e+01, 6.98104261e+01, 7.39077948e+02,
#        3.72910042e+02, 1.28497966e+02, 5.87435626e+02, 6.86296511e+02,
#        7.22376010e+02, 3.67484550e+00, 9.91444941e+01, 3.57516896e-03,
#        5.06327668e+02, 7.10746744e+02, 6.32011514e+02, 1.17720401e+02,
#        3.14287118e+02, 3.27993753e+02, 2.18780977e+01, 5.45484997e+02,
#        6.02585748e+01, 1.20799590e+02, 7.82817747e+01, 6.29950569e+02,
#        4.47740698e+01, 5.88932179e+02, 9.51578546e+01, 7.52399612e+02,
#        9.42731536e+00, 5.07261483e+02, 3.40862924e+02, 1.28876104e-01,
#        4.92219784e+02, 6.84580047e+01, 2.64273977e+01, 5.09231846e+02,
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(projection='polar')
plt.scatter(ang,y,c=ang,s=area)

# %%
import seaborn as sns
df=sns.load_dataset("dowjones")
df
# Out:
#            Date   Price
# 0    1914-12-01   55.00
# 1    1915-01-01   56.55
# 2    1915-02-01   56.00
# 3    1915-03-01   58.30
# 4    1915-04-01   66.45
# ..          ...     ...
# 644  1968-08-01  883.72
# 645  1968-09-01  922.80
# 646  1968-10-01  955.47
# 647  1968-11-01  964.12
# 648  1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
df=sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set(style='darkgrid')

# %%
sns.stripplot(data=df,x='species',y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
df1=sns.load_dataset("tips")
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(data=df1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set(style='whitegrid')

# %%
sns.stripplot(x=df1['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.stripplot(data=df1,x='day',y='total_bill',jitter=0.4)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=df1,x='day',y='total_bill',jitter=0.1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=df1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=df1,x='day',y='total_bill',linewidth=2,jitter=0.2)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#palette colors
#coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r,

#gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r,

#gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r,

# %%
plt.figure(figsize=(10,5))
sns.stripplot(data=df1,x='sex',y='total_bill',jitter=0.2,hue='day',alpha=0.8,size=15,marker='<',palette='gist_ncar')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(data=df1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=df1,x='sex',y='total_bill',palette='gist_ncar')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=df1,x='sex',y='total_bill',hue='day',palette='gist_ncar')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=df1,x='day',y='total_bill',hue='sex',palette='gist_ncar')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.countplot(data=df1,x='day')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(data=df1,x='day',hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxplot(data=df1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(df1['total_bill'])
# Out:
# C:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.violinplot(data=df1,x='total_bill',y='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(data=df1,x='day',y='total_bill',hue='sex',linewidth=4)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df1,x='day',y='total_bill',hue='sex',split=True,palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df1,x='day',y='tip',marker='<',hue='smoker',size=20)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.pairplot(df1,hue='smoker')

# %%
sns.pairplot(df1,hue='time')

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
x=np.random.randn(100)
x
# Out:
# array([ 1.7069894 , -0.96494923,  0.86811909, -0.54647257, -2.08987106,
#        -0.44560148,  0.01176487, -0.9255676 , -0.62117687, -0.18882176,
#         1.16178366,  1.94899188, -1.4620362 , -1.02906331, -0.45564568,
#        -0.96031219, -1.54188682, -2.41460344, -0.83428718,  0.11311986,
#         0.7207761 , -0.0715597 ,  0.72723584,  0.10341772, -0.94403868,
#         0.25345866, -0.97521401,  0.96848205,  0.33163769,  0.75298465,
#         0.66143174, -0.16198112, -0.97105313, -1.19978838, -0.58067048,
#         0.32531845,  0.75246069,  0.68911057, -2.47946388, -1.8223052 ,
#        -0.62126542,  1.500648  , -0.28672882,  1.96870901,  0.05594476,
#         1.85397327,  0.04340737, -1.32726367,  1.62371898, -0.18204924,
#        -0.12310166, -1.07976445, -0.10939638,  0.86610666,  0.04355436,
#        -0.06282116,  0.07810392, -0.99098177,  0.83852885, -0.41070983,
#         0.43000584,  1.3098527 , -1.46096147, -1.19528293,  0.16454338,
# ...

# %%
y=np.random.randn(100)
y
# Out:
# array([-1.4643328 , -0.99719256,  0.36234219, -0.54156928, -0.51190457,
#        -1.55547218,  1.62952489, -1.38843994, -0.00727587,  0.9813745 ,
#         0.26725959, -1.02372816, -0.67777334, -0.31874211,  1.24272738,
#        -0.00421838,  2.66137389, -1.87896559,  0.57074491,  0.42009657,
#         0.27681494,  0.87163267, -0.195401  , -1.45213394, -1.19309892,
#         0.01582881,  1.48600174, -0.81144869, -0.39982672,  1.60720444,
#         0.73510708, -1.55426024, -0.06785928,  0.0531033 , -1.06795009,
#        -0.74746334, -1.33501008,  0.28417303, -0.27302483, -0.03240163,
#        -2.18444946,  0.35603344,  0.25741065,  0.39221934, -0.25503378,
#         0.77766016, -0.76636974,  0.00731651, -0.5806422 , -0.56047015,
#        -0.75199802,  0.8329124 ,  0.65427499,  1.07008523,  0.38711886,
#        -0.93845129,  0.82706548,  0.18744477,  1.81551593,  0.62388228,
#         1.78087451, -0.92335718,  0.54939777,  0.84176404,  1.0214688 ,
# ...

# %%
sns.kdeplot(x)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(y)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(df1['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df1['tip'],shade=True,color='green')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(df1['tip'],shade=True,color='green',vertical=True)
# Out:
# C:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density', ylabel='tip'>

# %%
sns.kdeplot(x,y,shade=True)
# Out:
# C:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.kdeplot(data=df1,x='total_bill',y='tip',shade=True,cbar=True,cmap='Set2')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=df1,x='total_bill',y='tip',cbar=True,cmap='Set2')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.kdeplot(df['sepal_length'],df['sepal_width'])
sns.kdeplot(df['petal_length'],df['petal_width'])
# Out:
# C:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Joban Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>
