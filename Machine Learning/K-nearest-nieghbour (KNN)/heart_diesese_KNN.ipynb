# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hearts = pd.read_csv(r"C:\Users\Joban Chauhan\OneDrive\Desktop\Shikha Mam\heart.csv")

# %%
hearts
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
hearts.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
hearts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
sns.countplot(x="ChestPainType",data=hearts);

# %%
plt.figure(figsize=(12,7))
#sns.countplot(hearts.Age);
sns.countplot(x="Age",data=hearts);

# %%
sns.histplot(hearts.Age);

# %%
sns.countplot(x="Sex",data=hearts);

# %%
plt.figure(figsize=(25,12))
sns.countplot(x="RestingBP",data=hearts);

# %%
a = pd.get_dummies(hearts['ChestPainType'], prefix = "ChestPainType")
b = pd.get_dummies(hearts['RestingECG'], prefix = "RestingECG")
c = pd.get_dummies(hearts['ST_Slope'], prefix = "ST_Slope")
d = pd.get_dummies(hearts['Sex'], prefix = "Sex")
e = pd.get_dummies(hearts['ST_Slope'], prefix = "ExerciseAngina")

# %%
frames = [hearts, a, b, c,d,e]
hearts = pd.concat(frames, axis = 1)
hearts.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak  ... RestingECG_Normal  RestingECG_ST  \
# 0              N      0.0  ...                 1              0
# 1              N      1.0  ...                 1              0
# 2              N      0.0  ...                 0              1
# 3              Y      1.5  ...                 1              0
# 4              N      0.0  ...                 1              0
#
#    ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up  Sex_F  Sex_M  \
# ...

# %%
hearts = hearts.drop(columns = ['ChestPainType', 'RestingECG', 'ST_Slope','Sex','ExerciseAngina'])
hearts.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  ...  \
# 0                  0                  1                  0  ...
# 1                  0                  0                  1  ...
# 2                  0                  1                  0  ...
# 3                  1                  0                  0  ...
# 4                  0                  0                  1  ...
#
#    RestingECG_Normal  RestingECG_ST  ST_Slope_Down  ST_Slope_Flat  \
# 0                  1              0              0              0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y = hearts.HeartDisease.values
x_data = hearts.drop(['HeartDisease'], axis = 1)

# %%
x_data
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  \
# 0     40        140          289          0    172      0.0
# 1     49        160          180          0    156      1.0
# 2     37        130          283          0     98      0.0
# 3     48        138          214          0    108      1.5
# 4     54        150          195          0    122      0.0
# ..   ...        ...          ...        ...    ...      ...
# 913   45        110          264          0    132      1.2
# 914   68        144          193          1    141      3.4
# 915   57        130          131          0    115      1.2
# 916   57        130          236          0    174      0.0
# 917   38        138          175          0    173      0.0
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0                    0                  1                  0
# 1                    0                  0                  1
# ...

# %%
x = (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data)).values
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
