# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Joban Chauhan\Python\shikha mam\Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = df[["YearsExperience"]]

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y = df[["Salary"]]

# %%
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
# !pip install sklearn

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=3)

# %%
X_train
# Out:
#     YearsExperience
# 1               1.3
# 17              5.3
# 27              9.6
# 7               3.2
# 12              4.0
# 4               2.2
# 23              8.2
# 6               3.0
# 20              6.8
# 9               3.7
# 11              4.0
# 29             10.5
# 19              6.0
# 21              7.1
# 0               1.1
# 8               3.2
# 28             10.3
# 3               2.0
# 25              9.0
# 24              8.7
# 10              3.9

# %%
y_train
# Out:
#       Salary
# 1    46205.0
# 17   83088.0
# 27  112635.0
# 7    54445.0
# 12   56957.0
# 4    39891.0
# 23  113812.0
# 6    60150.0
# 20   91738.0
# 9    57189.0
# 11   55794.0
# 29  121872.0
# 19   93940.0
# 21   98273.0
# 0    39343.0
# 8    64445.0
# 28  122391.0
# 3    43525.0
# 25  105582.0
# 24  109431.0
# 10   63218.0

# %%
X_test
# Out:
#     YearsExperience
# 15              4.9
# 5               2.9
# 22              7.9
# 26              9.5
# 18              5.9
# 14              4.5
# 13              4.1
# 2               1.5
# 16              5.1

# %%
y_test
# Out:
#       Salary
# 15   67938.0
# 5    56642.0
# 22  101302.0
# 26  116969.0
# 18   81363.0
# 14   61111.0
# 13   57081.0
# 2    37731.0
# 16   66029.0

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred_xtest = LR.predict(X_test)
pred_xtest
# Out:
# array([[ 73289.5314978 ],
#        [ 54692.70041028],
#        [101184.77812906],
#        [116062.24299907],
#        [ 82587.94704155],
#        [ 69570.16528029],
#        [ 65850.79906279],
#        [ 41674.91864903],
#        [ 75149.21460655]])

# %%
pred_xtrain = LR.predict(X_train)
pred_xtrain
# Out:
# array([[ 39815.23554028],
#        [ 77008.8977153 ],
#        [116992.08455344],
#        [ 57482.22507341],
#        [ 64920.95750842],
#        [ 48183.80952966],
#        [103974.30279219],
#        [ 55622.54196466],
#        [ 90956.52103093],
#        [ 62131.43284529],
#        [ 64920.95750842],
#        [125360.65854282],
#        [ 83517.78859593],
#        [ 93746.04569406],
#        [ 37955.55243153],
#        [ 57482.22507341],
#        [123500.97543407],
#        [ 46324.12642091],
#        [111413.03522719],
#        [108623.51056406],
#        [ 63991.11595404]])

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train,y_train)
plt.plot(X_train,pred_xtrain,color = "r")

# %%
plt.scatter(X_test,y_test)
plt.plot(X_train,pred_xtrain,color = "r")

# %%
print("slope",LR.coef_)
# Out:
# slope [[9298.41554376]]

# %%
print("Intercept",LR.intercept_)
# Out:
# Intercept [27727.29533339]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from statsmodels.stats.outliers_influence import variance_inflation_factor
#       2 from sklearn.metrics import r2_score
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
r2_score(y_true=y_test,y_pred = pred_xtest)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,pred_xtest)

# %% [markdown]
# ### homoscedasticity -> all residual error`s variance is same

# %% [markdown]
# ### Gradient Decent->
#     iterative algorithm used to minimize the function(error/loss/cost)  by finding optimal parameter(a0,a1)

# %%
#y = a0 + a1*x

# %%
a0 = 2.70
a1 = 1.765

#y = a0 + a1*x
learning_rate = 0.01

# %%
def ms_error(y_true,y_pred):
    c = np.sum((y_true - y_pred)**2)/len(y_true)#Cost function 
    return c

def gd(x,y,iters = 1000 ,learning_rate = 0.0001):  # gradient Descent
    curr_wt = 0.1 #a1
    curr_bias = 0.01   #a0
    iteration = iters
    Lr = learning_rate
    n =len(x)

    wt =[]
    cost = []
    list_cost = []
    for i in range(iteration):
        predicted_y = curr_bias + (curr_wt*x)
        curr_cost = ms_error(y,predicted_y)
        #print(curr_cost)
        wt.append(curr_wt)
        cost.append(curr_bias)
        wd = -(2/n) * sum(x * (y-predicted_y)) 
        bd = -(2/n) * sum(y-predicted_y)
        curr_wt = curr_wt - (learning_rate*wd)
        curr_bias = curr_bias - (learning_rate*bd)
        print(f"Iteration no{i+1}, cost = {curr_cost}, bias = {curr_bias} , wt = {curr_wt}")
        plt.plot(wt,cost)
        plt.scatter(wt,cost,color = 'red')
        list_cost.append(curr_cost)
    print(wt[1])
    print(len(wt))
    print(list_cost[0])
    print(len(list_cost))
    print("ans",wt[list_cost.index(min(list_cost))])
    print(list_cost.index(min(list_cost)))
    print(min(list_cost))
    return curr_wt,curr_bias

def main():
    X = np.array([32.50234527, 53.42680403, 61.53035803, 47.47563963, 59.81320787,
           55.14218841, 52.21179669, 39.29956669, 48.10504169, 52.55001444,
           45.41973014, 54.35163488, 44.1640495 , 58.16847072, 56.72720806,
           48.95588857, 44.68719623, 60.29732685, 45.61864377, 38.81681754])
    
    Y = np.array([31.70700585, 68.77759598, 62.5623823 , 71.54663223, 87.23092513,
           78.21151827, 79.64197305, 59.17148932, 75.3312423 , 71.30087989,
           55.16567715, 82.47884676, 62.00892325, 75.39287043, 81.43619216,
           60.72360244, 82.89250373, 97.37989686, 48.84715332, 56.87721319])
    calc_wt,calc_bias = gd(X,Y)

# %%
if __name__ == "__main__":
    main()

# %%
# !python --version

# %%
# !pip install pyspark
# Out:
# ^C
