# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Joban Chauhan\Downloads\HistoricalGDTPriceIndex_historic.csv",parse_dates=["Trading Event Date"],index_col="Trading Event Date")

# %%
df.head()
# Out:
#                     Trading Event  GDT-AMF Price Index  GDT-SMP Price Index  \
# Trading Event Date
# 1999-01-01                   -113             546.4994             478.7078
# 1999-01-02                   -112             436.7185             466.9604
# 1999-01-03                   -111             415.6475             466.9604
# 1999-01-04                   -110             400.6380             453.7445
# 1999-01-05                   -109             398.3288             449.3392
#
#                     GDT-WMP Price Index  GDT Price Index  % Change AMF  \
# Trading Event Date
# 1999-01-01                     506.9503         521.7518           NaN
# 1999-01-02                     487.7477         497.1371       -0.2009
# 1999-01-03                     476.2261         489.0783       -0.0482
# 1999-01-04                     460.8639         473.9355       -0.0361
# 1999-01-05                     449.3423         465.6247       -0.0058
#
# ...

# %%
df.describe()
# Out:
#        Trading Event  GDT-AMF Price Index  GDT-SMP Price Index  \
# count     427.000000           427.000000           427.000000
# mean      100.000000          1093.067180           991.734422
# std       123.408536           479.241921           341.504913
# min      -113.000000           288.644100           422.907500
# 25%        -6.500000           721.469900           735.682800
# 50%       100.000000          1102.342500           928.359000
# 75%       206.500000          1481.299050          1210.076850
# max       313.000000          2023.180000          1951.600000
#
#        GDT-WMP Price Index  GDT Price Index  % Change AMF  % Change SMP  \
# count           427.000000       427.000000    426.000000    426.000000
# mean            972.464005       958.057426      0.004298      0.003867
# std             315.008334       284.681412      0.061224      0.055976
# min             374.452000       406.388600     -0.200900     -0.155000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 427 entries, 1999-01-01 to 2022-02-08
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Trading Event        427 non-null    int64
#  1   GDT-AMF Price Index  427 non-null    float64
#  2   GDT-SMP Price Index  427 non-null    float64
#  3   GDT-WMP Price Index  427 non-null    float64
#  4   GDT Price Index      427 non-null    float64
#  5   % Change AMF         426 non-null    float64
#  6   % Change SMP         426 non-null    float64
#  7   % Change WMP         426 non-null    float64
#  8   % Change GDT         426 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 33.4 KB

# %%
df.shape
# Out:
# (427, 9)

# %%
df.isnull().sum()
# Out:
# Trading Event          0
# GDT-AMF Price Index    0
# GDT-SMP Price Index    0
# GDT-WMP Price Index    0
# GDT Price Index        0
# % Change AMF           1
# % Change SMP           1
# % Change WMP           1
# % Change GDT           1
# dtype: int64

# %%
df.index
# Out:
# DatetimeIndex(['1999-01-01', '1999-01-02', '1999-01-03', '1999-01-04',
#                '1999-01-05', '1999-01-06', '1999-01-07', '1999-01-08',
#                '1999-01-09', '1999-01-10',
#                ...
#                '2022-03-15', '2022-05-04', '2022-04-19', '2022-03-05',
#                '2022-05-17', '2022-07-06', '2022-06-21', '2022-05-07',
#                '2022-07-19', '2022-02-08'],
#               dtype='datetime64[ns]', name='Trading Event Date', length=427, freq=None)

# %%
sns.pairplot(df)

# %%
df.groupby(df.index.year).sum()
# Out:
#                     Trading Event  GDT-AMF Price Index  GDT-SMP Price Index  \
# Trading Event Date
# 1999                        -1290            4963.7159            5575.7415
# 2000                        -1146            4215.6464            7966.3730
# 2001                        -1002            4292.6185            8754.0383
# 2002                         -858            3689.5447            5768.7224
# 2003                         -714            4655.8289            7364.1701
# 2004                         -570            5852.7394            8550.6609
# 2005                         -426            6951.5113            9407.4890
# 2006                         -282            6452.6381            9426.5784
# 2007                         -138           12201.9468           18303.9647
# 2008                            6           12878.3362           13869.3099
# 2009                          150            9952.3541            9611.6005
# ...

# %%
df.groupby(df.index.year).mean()
# Out:
#                     Trading Event  GDT-AMF Price Index  GDT-SMP Price Index  \
# Trading Event Date
# 1999                       -107.5           413.642992           464.645125
# 2000                        -95.5           351.303867           663.864417
# 2001                        -83.5           357.718208           729.503192
# 2002                        -71.5           307.462058           480.726867
# 2003                        -59.5           387.985742           613.680842
# 2004                        -47.5           487.728283           712.555075
# 2005                        -35.5           579.292608           783.957417
# 2006                        -23.5           537.719842           785.548200
# 2007                        -11.5          1016.828900          1525.330392
# 2008                          0.5          1073.194683          1155.775825
# 2009                         12.5           829.362842           800.966708
# ...

# %%
df.groupby([df.index.year,df.index.month]).mean()
# Out:
#                                        Trading Event  GDT-AMF Price Index  \
# Trading Event Date Trading Event Date
# 1999               1                          -107.5           413.642992
# 2000               1                           -95.5           351.303867
# 2001               1                           -83.5           357.718208
# 2002               1                           -71.5           307.462058
# 2003               1                           -59.5           387.985742
# ...                                              ...                  ...
# 2022               3                           305.5          1867.170000
#                    4                           302.5          1928.675000
#                    5                           308.0          1774.800000
#                    6                           310.0          1683.990000
#                    7                           310.5          1681.835000
#
# ...
